-- %%
-- Utilisez la table REGISTRY pour voir les versions et remplacez r2 par correlation
SELECT 
    model_version, 
    training_timestamp, 
    rmse, 
    mae, 
    correlation 
FROM taxi_mlops_prod.medoune_fall.ml_model_registry
ORDER BY training_timestamp DESC;
